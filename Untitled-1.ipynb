# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/2583048/4405830/adm_data.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221207%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221207T185128Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
print(df.shape)

## 9 rows , 400 columns
# Out:
# (400, 9)

# %%
print(df.columns)
###columns name
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.info()
### some general information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df["GRE Score"]= df["GRE Score"].astype("float64")
df.head()

##changing data type
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1      337.0          118                  4  4.5   4.5  9.65
# 1           2      324.0          107                  4  4.0   4.5  8.87
# 2           3      316.0          104                  3  3.0   3.5  8.00
# 3           4      322.0          110                  3  3.5   2.5  8.67
# 4           5      314.0          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df.describe(include=["int64"])
# Out:
#        Serial No.  TOEFL Score  University Rating    Research
# count  400.000000   400.000000         400.000000  400.000000
# mean   200.500000   107.410000           3.087500    0.547500
# std    115.614301     6.069514           1.143728    0.498362
# min      1.000000    92.000000           1.000000    0.000000
# 25%    100.750000   103.000000           2.000000    0.000000
# 50%    200.500000   107.000000           3.000000    1.000000
# 75%    300.250000   112.000000           4.000000    1.000000
# max    400.000000   120.000000           5.000000    1.000000

# %%
df["Research"].value_counts()
###number of people has reasearch exprience
# Out:
# 1    219
# 0    181
# Name: Research, dtype: int64

# %%
df.sort_values(by="SOP", ascending=False).head()

##sorting values
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 399         400      333.0          117                  4  5.0   4.0  9.66
# 151         152      332.0          116                  5  5.0   5.0  9.28
# 234         235      330.0          113                  5  5.0   4.0  9.31
# 215         216      330.0          116                  5  5.0   4.5  9.36
# 35           36      320.0          110                  5  5.0   5.0  9.20
#
#      Research  Chance of Admit
# 399         1              0.95
# 151         1              0.94
# 234         1              0.91
# 215         1              0.93
# 35          1              0.88

# %%
df.sort_values(by=["GRE Score", "CGPA"], ascending=[True, False]).head()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 377         378      290.0          100                  1  1.5   2.0  7.56
# 117         118      290.0          104                  4  2.0   2.5  7.46
# 168         169      293.0           97                  2  2.0   4.0  7.80
# 272         273      294.0           95                  1  1.5   1.5  7.64
# 79           80      294.0           93                  1  1.5   2.0  7.36
#
#      Research  Chance of Admit
# 377         0              0.47
# 117         0              0.45
# 168         1              0.64
# 272         0              0.49
# 79          0              0.46

# %%
df["SOP"].mean()
# Out:
# 3.4

# %%
df.iloc[0:10,0:8]
##indexing
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1      337.0          118                  4  4.5   4.5  9.65
# 1           2      324.0          107                  4  4.0   4.5  8.87
# 2           3      316.0          104                  3  3.0   3.5  8.00
# 3           4      322.0          110                  3  3.5   2.5  8.67
# 4           5      314.0          103                  2  2.0   3.0  8.21
# 5           6      330.0          115                  5  4.5   3.0  9.34
# 6           7      321.0          109                  3  3.0   4.0  8.20
# 7           8      308.0          101                  2  3.0   4.0  7.90
# 8           9      302.0          102                  1  2.0   1.5  8.00
# 9          10      323.0          108                  3  3.5   3.0  8.60
#
#    Research
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0
# 5         1
# 6         1
# 7         0
# 8         0
# 9         0

# %%
df[-1:]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 399         400      333.0          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 399         1              0.95

# %%
df[:1]
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1      337.0          118                  4  4.5   4.5  9.65
#
#    Research  Chance of Admit
# 0         1              0.92

# %%
df.apply(np.max)
##max of the whole columns
# Out:
# Serial No.           400.00
# GRE Score            340.00
# TOEFL Score          120.00
# University Rating      5.00
# SOP                    5.00
# LOR                    5.00
# CGPA                   9.92
# Research               1.00
# Chance of Admit        0.97
# dtype: float64

# %%
df.apply(np.min)
# Out:
# Serial No.             1.00
# GRE Score            290.00
# TOEFL Score           92.00
# University Rating      1.00
# SOP                    1.00
# LOR                    1.00
# CGPA                   6.80
# Research               0.00
# Chance of Admit        0.34
# dtype: float64
